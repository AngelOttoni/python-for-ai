# %% [markdown]
# # Python para Inteligência Artificial
# ---
#
# **Professor: Dr. Daniel Neri Cardoso**
#
# ## Módulo 5 — Matplotlib (Visualização)
#
# ### Lista de exercícios
#
#
# **Aluna: Angelina de Meiras Ottoni**

# %% [markdown]
# # =========================================
# # Exercise 1 — Distribuição de Dados
# # =========================================

# %%
# %pip install pandas

# %%
# %pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 299.6 kB/s eta 0:00:00a 0:00:01
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.62.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.5/117.5 kB 1.6 MB/s eta 0:00:00a 0:00:01
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy>=1.23 in /home/angel-ottoni/amo_projects/ppgmcs/python-for-ai/.my_venv/lib/python3.12/site-packages (from matplotlib) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/angel-ottoni/amo_projects/ppgmcs/python-for-ai/.my_venv/lib/python3.12/site-packages (from matplotlib) (26.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/angel-ottoni/amo_projects/ppgmcs/python-for-ai/.my_venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/angel-ottoni/amo_projects/ppgmcs/python-for-ai/.my_venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 6.0 MB/s eta 0:00:0000:0100:01
# Using cached contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 12.0 MB/s eta 0:00:0000:0100:01
# Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 7.0 MB/s eta 0:00:00:00:0100:01
# Downloading pillow-12.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 12.9 MB/s eta 0:00:0000:0100:01
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.8/122.8 kB 1.4 MB/s eta 0:00:00ta 0:00:01
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.1 kiwisolver-1.5.0 matplotlib-3.10.9 pillow-12.2.0 pyparsing-3.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the dataset
df = pd.read_excel('../data/processed/relatorio_final.xlsx')

# %%
df.head()
# Out:
#               Nome  Idade   Salario Departamento     Bonus
# 0       Joao Souza     27   3885.53       Vendas   388.553
# 1         Ana Lima     20   5985.67           RH   598.567
# 2   Helena Pereira     31  13986.53           TI  1398.653
# 3    Eduardo Souza     44   7478.16           TI   747.816
# 4  Maria Fernandes     37   6706.45       Vendas   670.645

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Nome          250 non-null    str
#  1   Idade         250 non-null    int64
#  2   Salario       250 non-null    float64
#  3   Departamento  250 non-null    str
#  4   Bonus         250 non-null    float64
# dtypes: float64(2), int64(1), str(2)
# memory usage: 9.9 KB

# %%
plt.hist(df['Salario'], bins=20, color='orchid')
plt.title("Salary Distribution in the Company")
plt.xlabel("Salary in BRL")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %% [markdown]
# # =========================================
# # Exercise 2 — Comparação Categórica
# # =========================================

# %%
department_counts = df['Departamento'].value_counts()

# %%
print(department_counts)
# Out:
# Departamento
# Vendas    124
# TI         85
# RH         41
# Name: count, dtype: int64

# %%
plt.bar(
    department_counts.index,
    department_counts.values,
    color='purple'
)
plt.title("Number of Employees by Department")
plt.xlabel("Department")
plt.ylabel("Number of Employees")

plt.show()

# %% [markdown]
# # =========================================
# # Exercise 3 — Correlação
# # =========================================

# %%
plt.scatter(
    df["Idade"],
    df["Salario"],
    color="green",
    alpha=0.6
)

plt.title("Age vs Salary")
plt.xlabel("Age")
plt.ylabel("Salary")

plt.show()

# %%
# Age of Clara using label
df['Idade'].max()
# Out:
# np.int64(65)

# %% [markdown]
# # =========================================
# # Exercise 4 — Mapeamento Rápido via Pandas
# # =========================================

# %%
# %pip install openpyxl

# %%
import openpyxl as open

# %%
df = pd.read_excel('../data/raw/funcionarios.xlsx')

# %%
display(df.head())
# Out:
#               Nome  Idade   Salario Departamento
# 0       Joao Souza   27.0   3885.53       Vendas
# 1         Ana Lima   20.0   5985.67           RH
# 2   Helena Pereira   31.0  13986.53           TI
# 3    Eduardo Souza   44.0   7478.16           TI
# 4  Maria Fernandes   37.0   6706.45       Vendas

# %%
df.shape
# Out:
# (250, 4)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Nome          250 non-null    str
#  1   Idade         225 non-null    float64
#  2   Salario       250 non-null    float64
#  3   Departamento  250 non-null    str
# dtypes: float64(2), str(2)
# memory usage: 7.9 KB

# %% [markdown]
# # =========================================
# # Exercise 5 — Proporções Relativas
# # =========================================

# %%
df.isnull().sum()
# Out:
# Nome             0
# Idade           25
# Salario          0
# Departamento     0
# dtype: int64

# %%
df['Idade'].unique()
# Out:
# array([27., 20., 31., 44., 37., 23., 39., 26., 36., 24., 41., 46., nan,
#        21., 40., 65., 45., 42., 43., 33., 30., 58., 18., 19., 28., 35.,
#        56., 32., 53., 22., 48., 34., 25., 51., 49., 47., 29., 38., 50.,
#        57., 54.])

# %%
df['Idade'].value_counts().head()
# Out:
# Idade
# 27.0    12
# 37.0    12
# 36.0    12
# 28.0    10
# 41.0     9
# Name: count, dtype: int64

# %% [markdown]
# # =========================================
# # Exercise 6 — Salvando para Artigos/Relatórios
# # =========================================

# %%
# Mean age
mean_age = df['Idade'].mean()

print(mean_age)
# Out:
# 35.61333333333334

# %%
# Fill missing values with mean (imputation)
df['Idade'] = df['Idade'].fillna(mean_age)

# %%
# Inspect values before rounding
df['Idade'].unique()
# Out:
# array([27.        , 20.        , 31.        , 44.        , 37.        ,
#        23.        , 39.        , 26.        , 36.        , 24.        ,
#        41.        , 46.        , 35.61333333, 21.        , 40.        ,
#        65.        , 45.        , 42.        , 43.        , 33.        ,
#        30.        , 58.        , 18.        , 19.        , 28.        ,
#        35.        , 56.        , 32.        , 53.        , 22.        ,
#        48.        , 34.        , 25.        , 51.        , 49.        ,
#        47.        , 29.        , 38.        , 50.        , 57.        ,
#        54.        ])

# %%
df['Idade'].value_counts().head()
# Out:
# Idade
# 35.613333    25
# 27.000000    12
# 37.000000    12
# 36.000000    12
# 28.000000    10
# Name: count, dtype: int64

# %%
# Inspect distribution after imputation
df.describe()
# Out:
#             Idade       Salario
# count  250.000000    250.000000
# mean    35.613333   7272.971880
# std      9.166326   3026.235709
# min     18.000000   2184.180000
# 25%     29.000000   5025.972500
# 50%     35.613333   6757.065000
# 75%     41.000000   9160.692500
# max     65.000000  14974.620000

# %%
# Round and convert to integer to preserve semantic meaning of age
df['Idade'] = df['Idade'].round().astype(int)

# %%
df['Idade'].unique()
# Out:
# array([27, 20, 31, 44, 37, 23, 39, 26, 36, 24, 41, 46, 21, 40, 65, 45, 42,
#        43, 33, 30, 58, 18, 19, 28, 35, 56, 32, 53, 22, 48, 34, 25, 51, 49,
#        47, 29, 38, 50, 57, 54])

# %%
df['Idade'].value_counts().head()
# Out:
# Idade
# 36    37
# 27    12
# 37    12
# 28    10
# 41     9
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#             Idade       Salario
# count  250.000000    250.000000
# mean    35.652000   7272.971880
# std      9.167063   3026.235709
# min     18.000000   2184.180000
# 25%     29.000000   5025.972500
# 50%     36.000000   6757.065000
# 75%     41.000000   9160.692500
# max     65.000000  14974.620000

# %% [markdown]
# ⚠️ **Observação sobre precisão dos dados**
#
# Embora neste caso tenha sido realizado o arredondamento da variável `Idade`, é importante destacar que essa decisão depende do contexto dos dados.
#
# *Caso os dados reais apresentem valores contínuos (com casas decimais), essa precisão deve ser preservada, evitando arredondamentos que possam levar à perda de informação ou distorção da distribuição original.*

# %% [markdown]
# # =========================================
# # Exercise 7 — Seleção Lógica
# # =========================================

# %%
df_ti_senior = df[(df['Departamento'] == 'TI') & (df['Salario'] > 8000)]

# Count how many
len(df_ti_senior)
# Out:
# 59

# %% [markdown]
# # =========================================
# # Exercise 8 — Criação de Colunas
# # =========================================

# %%
df['Bonus'] = df['Salario'] * 0.10

# %%
df.head()
# Out:
#               Nome  Idade   Salario Departamento     Bonus
# 0       Joao Souza     27   3885.53       Vendas   388.553
# 1         Ana Lima     20   5985.67           RH   598.567
# 2   Helena Pereira     31  13986.53           TI  1398.653
# 3    Eduardo Souza     44   7478.16           TI   747.816
# 4  Maria Fernandes     37   6706.45       Vendas   670.645

# %% [markdown]
# # =========================================
# # Exercise 9 — Estatística Descritiva
# # =========================================

# %%
df['Departamento'].value_counts()
# Out:
# Departamento
# Vendas    124
# TI         85
# RH         41
# Name: count, dtype: int64

# %% [markdown]
# # =========================================
# # Exercise 10 — Exportação
# # =========================================

# %%
df.to_excel('../data/processed/relatorio_final.xlsx', index=False)
