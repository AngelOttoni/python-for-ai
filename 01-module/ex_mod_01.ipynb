# %% [markdown]
# # Python para Inteligência Artificial
# ---
#
# ## Módulo 1 - Fundamentos e Lógica
#
# ### Lista de exercícios
#
#
# **Aluna: Angelina de Meiras Ottoni**

# %% [markdown]
# #### Exercício 1
